# %% [markdown]
# # Delta imcoming / outgoing bikes

# %%
#general imports
import pandas as pd
import numpy as np

#statsmodels for regression
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

#scipy for testing
from scipy import stats

#for visualization
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta

# %%
df_bikes = pd.read_csv('../data/philadelphia_2017.csv')
df_weather = pd.read_csv('../data/weather_hourly_philadelphia.csv')

def get_datetime(date_string):
    if date_string.__contains__("/"):
        new_string = ""
        running_string = ""
        for char in date_string:
            if char == "/" or  char == ":" or char == " ":
                if len(running_string) == 1:
                    running_string = "0" + running_string
                new_string += running_string + char
                running_string = ""
            else:
                running_string += char
        new_string += running_string
        if len(new_string) > 16:
            return datetime.strptime(new_string, '%m/%d/%Y %H:%M:%S')
        else:
            return datetime.strptime(new_string, '%m/%d/%Y %H:%M')
    else:
        return datetime.fromisoformat(date_string)

def compare_datetime(start, end):
    start_datetime = get_datetime(start)
    end_datetime = get_datetime(end)
    duration_of_travel = end_datetime - start_datetime
    seconds = duration_of_travel.total_seconds()
    return seconds/60

ride_lengths = []
df_bikes["ride_duration_minutes"] = df_bikes.apply(lambda x: (compare_datetime(x["start_time"],x["end_time"])), axis=1)

for label, content in df_bikes.iterrows():
    ride_lengths.append(content["ride_duration_minutes"])

ride_lengths_np = np.array(ride_lengths)
iqr = stats.iqr(ride_lengths_np)
iqr

q1,q3 = np.percentile(ride_lengths_np, [25,95])

lower_range = q1 - (1.5*iqr)
upper_range = q3 + (1.5*iqr)

#A ride, can't be shorter than 0 Minutes obviously
if lower_range < 0:
    lower_range = 0

df_bikes.drop(df_bikes[ (df_bikes.ride_duration_minutes > upper_range) | (df_bikes.ride_duration_minutes < lower_range) ].index , inplace=True)

# %% [markdown]
# Rounding times to minutes

# %%
s = 0
z = 1
for x in range(0,788906):
    if x not in df_bikes.index:
        s = s + 1
        if s == 1000*z:
            print(x/788906)
            z = z + 1
        else:
            pass
    else:
        df_bikes['start_time_rounded'][x] = get_datetime(df_bikes["start_time"][x]).replace(minute=0)
        df_bikes['end_time_rounded'][x] = get_datetime(df_bikes["end_time"][x]).replace(minute=0)
# Out:
# <ipython-input-316-195cadd1e3e5>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['start_time_rounded'][x] = get_datetime(df_bikes["start_time"][x]).replace(minute=0)
# <ipython-input-316-195cadd1e3e5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['end_time_rounded'][x] = get_datetime(df_bikes["end_time"][x]).replace(minute=0)
# 0.05804874091463368
# 0.08382874512299311
# 0.13764757778493256
# 0.16717707813098137
# 0.19686249058823233
# 0.2343067488395322
# 0.27538261846151507
# 0.30219823401013557
# 0.34052472664677413
# 0.3716501078708997
# 0.40765566493346483
# 0.43515450509946685
# 0.46883278869725925
# 0.5060704317117629
# 0.5477230493873795
# 0.579788973591277
# 0.6180913822432584
# 0.6582850174799025
# 0.6859739943668828
# 0.7313152644294758
# 0.7698521750373302
# 0.8191191345990524
# 0.8593343186640741
# 0.9027361941726898
# 0.9612095737641747

# %%
df_bikes_delta_outgoing_support = df_bikes.groupby(['start_station_name','start_time_rounded']).count().reset_index()
df_bikes_delta_incoming_support = df_bikes.groupby(['end_station_name','end_time_rounded']).count().reset_index()

# %%
df_bikes_delta_outgoing_support = df_bikes_delta_outgoing_support.sort_values(['start_station_name', 'start_time_rounded'])
df_bikes_delta_incoming_support = df_bikes_delta_incoming_support.sort_values(['end_station_name', 'end_time_rounded'])

# %%
beginning = df_bikes_delta_outgoing_support["start_time_rounded"][0]
print(beginning)
# Out:
# 2017-01-01 00:00:00

# %%
df_stations = df_bikes_delta_outgoing_support['start_station_name'].unique()

# %%
df_stations
# Out:
# array(['10th & Chestnut', '10th & Federal', '11th & Pine, Kahn Park',
#        '11th & Poplar, John F. Street Community Center', '11th & Reed',
#        '11th & South', '11th & Washington', '12th & Callowhill',
#        '12th & Filbert', '12th & Passyunk', '13th & Locust',
#        '13th & Montgomery', '15th & Castle, DiSilvestro Playground',
#        '15th & Market', '15th & South', '15th & Spruce', '17th & Girard',
#        '17th & Pine', '17th & Spring Garden',
#        '18th & Fernon, Aquinas Center', '18th & JFK',
#        '18th & Washington, Chew Playground', '19th & Girard, PTTI',
#        '19th & Lombard', '19th & Market', '20th & Fairmount',
#        '20th & Market', '20th & Sansom', '21st & Catharine',
#        '21st & Winter, Franklin Institute', '22nd & Cecil B. Moore',
#        '22nd & Federal', '23rd & Fairmount', '23rd & Market',
#        '23rd & South', '24th & Cecil B. Moore, Cecil B. Moore Library',
#        '24th & Race SRT', '24th & Sansom', '25th & Locust',
#        '27th & Girard', '27th & Master, Athletic Recreation Center',
#        '27th & South', '29th & Dauphin', '29th & Diamond',
#        '2nd & Germantown', '2nd & Market', '2nd & Race', '2nd & South',
#        '3083', '30th Street Station East', '31st & Girard',
#        '32nd & Baring, Drexel Park', '33rd & Dauphin', '33rd & Diamond',
#        '33rd & Market', '33rd & Reservoir', '34th & Mantua',
#        '36th & Sansom', '38th & Market', '38th & Powelton',
#        '38th & Spruce',
#        '39th & Mt. Vernon, Mantua Haverford Community Center',
#        '3rd & Girard', '40th & Baltimore, Trolley Portal',
#        '40th & Spruce', '40th Street Station, MFL', '42nd & Lancaster',
#        '43rd & Chester, Clark Park', '44th & Walnut',
#        '46th Street Station, MFL', '48th & Spruce', '4th & Bainbridge',
#        '4th & Christian', '4th & Walnut, NPS', '4th & Washington',
#        '6th & Berks', '6th & Fairmount', '6th & Race', '7th & Fitzwater',
#        '8th & Market', '8th & Mifflin, Bok Building', '9th & Arch',
#        '9th & Locust', '9th & Spring Garden',
#        'Amtrak 30th Street Station', 'Barnes Foundation',
#        'Berks Station, MFL', 'Broad & Christian', 'Broad & Federal',
#        'Broad & Girard', 'Broad & Oxford', 'Broad & Passyunk',
#        'Darien & Catharine', 'Del. River Trail & Penn St.',
#        'Dornsife Center', 'Fairmount & Ridge', 'Foglietta Plaza',
#        'Free Library of Philadelphia - Central Library',
#        'Front & Carpenter', 'Girard & Hutchinson', 'Girard Station, MFL',
#        'Grays Ferry & Pemberton', 'Independence Mall, NPS',
#        'Moyamensing & Tasker', 'Municipal Services Building Plaza',
#        'ParkWest Town Center', 'Parkside & Belmont, Case Building',
#        'Parkside & Girard', 'Penn Treaty Park',
#        'Pennsylvania & Fairmount Perelman Building',
#        'Pennsylvania Convention Center', 'Philadelphia Museum of Art',
#        'Philadelphia Zoo', 'Point Breeze & Tasker', 'Race Street Pier',
#        'Rittenhouse Square', 'Rodin Museum', 'Spring Garden Station, BSL',
#        'Spring Garden Station, MFL', 'Temple University Station',
#        "The Children's Hospital of Philadelphia (CHOP)",
#        "The Children's Hospital of Philadelphia, Osler Circle",
#        'Thompson & Palmer, Adaire School', 'University City Station',
#        'Virtual Station', 'Welcome Park, NPS'], dtype=object)

# %%
df_bikes_delta_o_support = df_bikes_delta_outgoing_support[['start_station_name','start_time_rounded','start_time']].copy()
df_bikes_o_delta = df_bikes_delta_o_support.rename(columns = {'start_station_name': 'Station Name', 'start_time_rounded': 'Time', 'start_time': 'Outgoing bikes'}, inplace = False)

# %%
df_bikes_delta_i_support = df_bikes_delta_incoming_support[['end_station_name','end_time_rounded','end_time']].copy()
df_bikes_i_delta = df_bikes_delta_i_support.rename(columns = {'end_station_name': 'Station Name', 'end_time_rounded': 'Time', 'end_time': 'Incoming bikes'}, inplace = False)

# %%
df_bikes_o_delta.head(10)
# Out:
#       Station Name                Time  Outgoing bikes
# 0  10th & Chestnut 2017-01-01 00:00:00               1
# 1  10th & Chestnut 2017-01-01 10:00:00               1
# 2  10th & Chestnut 2017-01-01 15:00:00               2
# 3  10th & Chestnut 2017-01-01 16:00:00               2
# 4  10th & Chestnut 2017-01-01 17:00:00               1
# 5  10th & Chestnut 2017-01-01 18:00:00               1
# 6  10th & Chestnut 2017-01-02 00:00:00               1
# 7  10th & Chestnut 2017-01-02 08:00:00               2
# 8  10th & Chestnut 2017-01-02 09:00:00               1
# 9  10th & Chestnut 2017-01-02 18:00:00               1

# %%
for m in range(0, df_stations.size):
    for n in range(0 , 8759):
        df_bikes_o_delta_support_new = {'Station Name': df_stations[m], 'Time': beginning + timedelta(hours=n), 'Outgoing bikes': 0}
        df_bikes_o_delta = df_bikes_o_delta.append(df_bikes_o_delta_support_new, ignore_index=True)
    print(df_stations[m])
# Out:
# 10th & Chestnut
# 10th & Federal
# 11th & Pine, Kahn Park
# 11th & Poplar, John F. Street Community Center
# 11th & Reed
# 11th & South
# 11th & Washington
# 12th & Callowhill
# 12th & Filbert
# 12th & Passyunk
# 13th & Locust
# 13th & Montgomery
# 15th & Castle, DiSilvestro Playground
# 15th & Market
# 15th & South
# 15th & Spruce
# 17th & Girard
# 17th & Pine
# 17th & Spring Garden
# 18th & Fernon, Aquinas Center
# 18th & JFK
# 18th & Washington, Chew Playground
# 19th & Girard, PTTI
# 19th & Lombard
# 19th & Market
# 20th & Fairmount
# 20th & Market
# 20th & Sansom
# 21st & Catharine
# 21st & Winter, Franklin Institute
# 22nd & Cecil B. Moore
# 22nd & Federal
# 23rd & Fairmount
# 23rd & Market
# 23rd & South
# 24th & Cecil B. Moore, Cecil B. Moore Library
# 24th & Race SRT
# 24th & Sansom
# 25th & Locust
# 27th & Girard
# 27th & Master, Athletic Recreation Center
# 27th & South
# 29th & Dauphin
# 29th & Diamond
# 2nd & Germantown
# 2nd & Market
# 2nd & Race
# 2nd & South
# 3083
# 30th Street Station East
# 31st & Girard
# 32nd & Baring, Drexel Park
# 33rd & Dauphin
# 33rd & Diamond
# 33rd & Market
# 33rd & Reservoir
# 34th & Mantua
# 36th & Sansom
# 38th & Market
# 38th & Powelton
# 38th & Spruce
# 39th & Mt. Vernon, Mantua Haverford Community Center
# 3rd & Girard
# 40th & Baltimore, Trolley Portal
# 40th & Spruce
# 40th Street Station, MFL
# 42nd & Lancaster
# 43rd & Chester, Clark Park
# 44th & Walnut
# 46th Street Station, MFL
# 48th & Spruce
# 4th & Bainbridge
# 4th & Christian
# 4th & Walnut, NPS
# 4th & Washington
# 6th & Berks
# 6th & Fairmount
# 6th & Race
# 7th & Fitzwater
# 8th & Market
# 8th & Mifflin, Bok Building
# 9th & Arch
# 9th & Locust
# 9th & Spring Garden
# Amtrak 30th Street Station
# Barnes Foundation
# Berks Station, MFL
# Broad & Christian
# Broad & Federal
# Broad & Girard
# Broad & Oxford
# Broad & Passyunk
# Darien & Catharine
# Del. River Trail & Penn St.
# Dornsife Center
# Fairmount & Ridge
# Foglietta Plaza
# Free Library of Philadelphia - Central Library
# Front & Carpenter
# Girard & Hutchinson
# Girard Station, MFL
# Grays Ferry & Pemberton
# Independence Mall, NPS
# Moyamensing & Tasker
# Municipal Services Building Plaza
# ParkWest Town Center
# Parkside & Belmont, Case Building
# Parkside & Girard
# Penn Treaty Park
# Pennsylvania & Fairmount Perelman Building
# Pennsylvania Convention Center
# Philadelphia Museum of Art
# Philadelphia Zoo
# Point Breeze & Tasker
# Race Street Pier
# Rittenhouse Square
# Rodin Museum
# Spring Garden Station, BSL
# Spring Garden Station, MFL
# Temple University Station
# The Children's Hospital of Philadelphia (CHOP)
# The Children's Hospital of Philadelphia, Osler Circle
# Thompson & Palmer, Adaire School
# University City Station
# Virtual Station
# Welcome Park, NPS

# %%
df_bikes_o_delta.head(10)
# Out:
#       Station Name                Time  Outgoing bikes
# 0  10th & Chestnut 2017-01-01 00:00:00               1
# 1  10th & Chestnut 2017-01-01 10:00:00               1
# 2  10th & Chestnut 2017-01-01 15:00:00               2
# 3  10th & Chestnut 2017-01-01 16:00:00               2
# 4  10th & Chestnut 2017-01-01 17:00:00               1
# 5  10th & Chestnut 2017-01-01 18:00:00               1
# 6  10th & Chestnut 2017-01-02 00:00:00               1
# 7  10th & Chestnut 2017-01-02 08:00:00               2
# 8  10th & Chestnut 2017-01-02 09:00:00               1
# 9  10th & Chestnut 2017-01-02 18:00:00               1

# %%
df_bikes_i_delta = df_bikes_o_delta

# %%
df_stations.size
# Out:
# 126

# %%
for m in range(0, df_stations.size):
        df_bikes_i_delta_support_new = {'Station Name': df_stations[m], 'Time': beginning + timedelta(hours=8759), 'Outgoing bikes': 0}
        df_bikes_i_delta = df_bikes_i_delta.append(df_bikes_i_delta_support_new, ignore_index=True)

# %%
df_bikes_i_delta.tail(20)
# Out:
#                                               Station Name  \
# 1454973                  Parkside & Belmont, Case Building
# 1454974                                  Parkside & Girard
# 1454975                                   Penn Treaty Park
# 1454976         Pennsylvania & Fairmount Perelman Building
# 1454977                     Pennsylvania Convention Center
# 1454978                         Philadelphia Museum of Art
# 1454979                                   Philadelphia Zoo
# 1454980                              Point Breeze & Tasker
# 1454981                                   Race Street Pier
# 1454982                                 Rittenhouse Square
# 1454983                                       Rodin Museum
# 1454984                         Spring Garden Station, BSL
# 1454985                         Spring Garden Station, MFL
# 1454986                          Temple University Station
# 1454987     The Children's Hospital of Philadelphia (CHOP)
# 1454988  The Children's Hospital of Philadelphia, Osler...
# 1454989                   Thompson & Palmer, Adaire School
# 1454990                            University City Station
# 1454991                                    Virtual Station
# 1454992                                  Welcome Park, NPS
#
#                        Time  Outgoing bikes
# 1454973 2017-12-31 23:00:00               0
# 1454974 2017-12-31 23:00:00               0
# 1454975 2017-12-31 23:00:00               0
# 1454976 2017-12-31 23:00:00               0
# 1454977 2017-12-31 23:00:00               0
# 1454978 2017-12-31 23:00:00               0
# 1454979 2017-12-31 23:00:00               0
# 1454980 2017-12-31 23:00:00               0
# 1454981 2017-12-31 23:00:00               0
# 1454982 2017-12-31 23:00:00               0
# 1454983 2017-12-31 23:00:00               0
# 1454984 2017-12-31 23:00:00               0
# 1454985 2017-12-31 23:00:00               0
# 1454986 2017-12-31 23:00:00               0
# 1454987 2017-12-31 23:00:00               0
# 1454988 2017-12-31 23:00:00               0
# 1454989 2017-12-31 23:00:00               0
# 1454990 2017-12-31 23:00:00               0
# 1454991 2017-12-31 23:00:00               0
# 1454992 2017-12-31 23:00:00               0

# %%
df_bikes_i_delta = df_bikes_i_delta.drop_duplicates(subset=['Station Name', 'Time'], keep='last', ignore_index=False)

# %%
df_bikes_i_delta = df_bikes_i_delta.rename(columns = {'Outgoing bikes': 'Incoming bikes'})

# %%
df_bikes_i_delta
# Out:
#                                               Station Name  \
# 351233                                     10th & Chestnut
# 351234                                     10th & Chestnut
# 351235                                     10th & Chestnut
# 351236                                     10th & Chestnut
# 351237                                     10th & Chestnut
# ...                                                    ...
# 1454988  The Children's Hospital of Philadelphia, Osler...
# 1454989                   Thompson & Palmer, Adaire School
# 1454990                            University City Station
# 1454991                                    Virtual Station
# 1454992                                  Welcome Park, NPS
#
#                        Time  Incoming bikes
# 351233  2017-01-01 00:00:00               0
# 351234  2017-01-01 01:00:00               0
# 351235  2017-01-01 02:00:00               0
# 351236  2017-01-01 03:00:00               0
# 351237  2017-01-01 04:00:00               0
# ...                     ...             ...
# 1454988 2017-12-31 23:00:00               0
# 1454989 2017-12-31 23:00:00               0
# 1454990 2017-12-31 23:00:00               0
# 1454991 2017-12-31 23:00:00               0
# 1454992 2017-12-31 23:00:00               0
#
# [1103760 rows x 3 columns]

# %%
df_bikes_delta_i_support = df_bikes_delta_incoming_support[['end_station_name','end_time_rounded','end_time']].copy()
df_bikes_delta_i_support = df_bikes_delta_i_support.rename(columns = {'end_station_name': 'Station Name', 'end_time_rounded': 'Time', 'end_time': 'Incoming bikes'}, inplace = False)
df_bikes_i_delta = df_bikes_i_delta.append(df_bikes_delta_i_support, ignore_index=True)

# %%
df_bikes_i_delta = df_bikes_i_delta.drop_duplicates(subset=['Station Name', 'Time'], keep='last', ignore_index=False)

# %%
df_bikes_i_delta
# Out:
#               Station Name                Time  Incoming bikes
# 0          10th & Chestnut 2017-01-01 00:00:00               0
# 1          10th & Chestnut 2017-01-01 01:00:00               0
# 2          10th & Chestnut 2017-01-01 02:00:00               0
# 3          10th & Chestnut 2017-01-01 03:00:00               0
# 4          10th & Chestnut 2017-01-01 04:00:00               0
# ...                    ...                 ...             ...
# 1446668  Welcome Park, NPS 2017-12-28 18:00:00               1
# 1446669  Welcome Park, NPS 2017-12-29 14:00:00               1
# 1446670  Welcome Park, NPS 2017-12-29 15:00:00               1
# 1446671  Welcome Park, NPS 2017-12-29 22:00:00               1
# 1446672  Welcome Park, NPS 2017-12-30 00:00:00               1
#
# [1103760 rows x 3 columns]

# %%
df_bikes_i_delta = df_bikes_i_delta.sort_values(['Station Name', 'Time'])
df_bikes_i_delta['Order'] = np.arange(len(df_bikes_i_delta))
df_bikes_i_delta = df_bikes_i_delta.set_index('Order')

# %%
df_bikes_i_delta
# Out:
#               Station Name                Time  Incoming bikes
# Order
# 0          10th & Chestnut 2017-01-01 00:00:00               0
# 1          10th & Chestnut 2017-01-01 01:00:00               0
# 2          10th & Chestnut 2017-01-01 02:00:00               0
# 3          10th & Chestnut 2017-01-01 03:00:00               0
# 4          10th & Chestnut 2017-01-01 04:00:00               0
# ...                    ...                 ...             ...
# 1103755  Welcome Park, NPS 2017-12-31 19:00:00               0
# 1103756  Welcome Park, NPS 2017-12-31 20:00:00               0
# 1103757  Welcome Park, NPS 2017-12-31 21:00:00               0
# 1103758  Welcome Park, NPS 2017-12-31 22:00:00               0
# 1103759  Welcome Park, NPS 2017-12-31 23:00:00               0
#
# [1103760 rows x 3 columns]

# %%
df_bikes_o_delta = df_bikes_o_delta.drop_duplicates(subset=['Station Name', 'Time'], keep='first', ignore_index=False)
df_bikes_o_delta = df_bikes_o_delta.sort_values(['Station Name', 'Time'])
df_bikes_o_delta['Order'] = np.arange(len(df_bikes_o_delta))
df_bikes_o_delta = df_bikes_o_delta.set_index('Order')

# %%
for m in range(0, df_stations.size):
        df_bikes_o_delta_support_new = {'Station Name': df_stations[m], 'Time': beginning + timedelta(hours=8759), 'Outgoing bikes': 0}
        df_bikes_o_delta = df_bikes_o_delta.append(df_bikes_o_delta_support_new, ignore_index=True)

# %%
df_bikes_o_delta = df_bikes_o_delta.drop_duplicates(subset=['Station Name', 'Time'], keep='first', ignore_index=False)
df_bikes_o_delta = df_bikes_o_delta.sort_values(['Station Name', 'Time'])
df_bikes_o_delta['Order'] = np.arange(len(df_bikes_o_delta))
df_bikes_o_delta = df_bikes_o_delta.set_index('Order')

# %%
df_bikes_o_delta
# Out:
#               Station Name                Time  Outgoing bikes
# Order
# 0          10th & Chestnut 2017-01-01 00:00:00               1
# 1          10th & Chestnut 2017-01-01 01:00:00               0
# 2          10th & Chestnut 2017-01-01 02:00:00               0
# 3          10th & Chestnut 2017-01-01 03:00:00               0
# 4          10th & Chestnut 2017-01-01 04:00:00               0
# ...                    ...                 ...             ...
# 1103755  Welcome Park, NPS 2017-12-31 19:00:00               0
# 1103756  Welcome Park, NPS 2017-12-31 20:00:00               0
# 1103757  Welcome Park, NPS 2017-12-31 21:00:00               0
# 1103758  Welcome Park, NPS 2017-12-31 22:00:00               0
# 1103759  Welcome Park, NPS 2017-12-31 23:00:00               0
#
# [1103760 rows x 3 columns]

# %%
df_bikes_delta_final = df_bikes_o_delta

# %%
df_bikes_delta_final['Incoming bikes'] = df_bikes_i_delta['Incoming bikes']

# %%
df_bikes_delta_final.head(50)
# Out:
#           Station Name                Time  Outgoing bikes  Incoming bikes
# Order
# 0      10th & Chestnut 2017-01-01 00:00:00               1               0
# 1      10th & Chestnut 2017-01-01 01:00:00               0               0
# 2      10th & Chestnut 2017-01-01 02:00:00               0               0
# 3      10th & Chestnut 2017-01-01 03:00:00               0               0
# 4      10th & Chestnut 2017-01-01 04:00:00               0               0
# 5      10th & Chestnut 2017-01-01 05:00:00               0               1
# 6      10th & Chestnut 2017-01-01 06:00:00               0               1
# 7      10th & Chestnut 2017-01-01 07:00:00               0               0
# 8      10th & Chestnut 2017-01-01 08:00:00               0               0
# 9      10th & Chestnut 2017-01-01 09:00:00               0               0
# 10     10th & Chestnut 2017-01-01 10:00:00               1               0
# 11     10th & Chestnut 2017-01-01 11:00:00               0               0
# 12     10th & Chestnut 2017-01-01 12:00:00               0               0
# 13     10th & Chestnut 2017-01-01 13:00:00               0               1
# 14     10th & Chestnut 2017-01-01 14:00:00               0               0
# 15     10th & Chestnut 2017-01-01 15:00:00               2               0
# 16     10th & Chestnut 2017-01-01 16:00:00               2               0
# 17     10th & Chestnut 2017-01-01 17:00:00               1               0
# 18     10th & Chestnut 2017-01-01 18:00:00               1               1
# 19     10th & Chestnut 2017-01-01 19:00:00               0               0
# 20     10th & Chestnut 2017-01-01 20:00:00               0               1
# 21     10th & Chestnut 2017-01-01 21:00:00               0               1
# 22     10th & Chestnut 2017-01-01 22:00:00               0               0
# 23     10th & Chestnut 2017-01-01 23:00:00               0               0
# 24     10th & Chestnut 2017-01-02 00:00:00               1               0
# 25     10th & Chestnut 2017-01-02 01:00:00               0               0
# 26     10th & Chestnut 2017-01-02 02:00:00               0               0
# 27     10th & Chestnut 2017-01-02 03:00:00               0               0
# 28     10th & Chestnut 2017-01-02 04:00:00               0               0
# 29     10th & Chestnut 2017-01-02 05:00:00               0               1
# 30     10th & Chestnut 2017-01-02 06:00:00               0               0
# 31     10th & Chestnut 2017-01-02 07:00:00               0               0
# 32     10th & Chestnut 2017-01-02 08:00:00               2               2
# 33     10th & Chestnut 2017-01-02 09:00:00               1               0
# 34     10th & Chestnut 2017-01-02 10:00:00               0               0
# 35     10th & Chestnut 2017-01-02 11:00:00               0               1
# 36     10th & Chestnut 2017-01-02 12:00:00               0               1
# 37     10th & Chestnut 2017-01-02 13:00:00               0               0
# 38     10th & Chestnut 2017-01-02 14:00:00               0               0
# 39     10th & Chestnut 2017-01-02 15:00:00               0               0
# 40     10th & Chestnut 2017-01-02 16:00:00               0               0
# 41     10th & Chestnut 2017-01-02 17:00:00               0               0
# 42     10th & Chestnut 2017-01-02 18:00:00               1               1
# 43     10th & Chestnut 2017-01-02 19:00:00               0               0
# 44     10th & Chestnut 2017-01-02 20:00:00               0               0
# 45     10th & Chestnut 2017-01-02 21:00:00               0               0
# 46     10th & Chestnut 2017-01-02 22:00:00               0               1
# 47     10th & Chestnut 2017-01-02 23:00:00               0               0
# 48     10th & Chestnut 2017-01-03 00:00:00               0               0
# 49     10th & Chestnut 2017-01-03 01:00:00               1               0

# %%
df_bikes_delta_final['Delta'] = df_bikes_delta_final['Incoming bikes'] - df_bikes_delta_final['Outgoing bikes']

# %%
df_bikes_delta_final.head(20)
# Out:
#           Station Name                Time  Outgoing bikes  Incoming bikes  \
# Order
# 0      10th & Chestnut 2017-01-01 00:00:00               1               0
# 1      10th & Chestnut 2017-01-01 01:00:00               0               0
# 2      10th & Chestnut 2017-01-01 02:00:00               0               0
# 3      10th & Chestnut 2017-01-01 03:00:00               0               0
# 4      10th & Chestnut 2017-01-01 04:00:00               0               0
# 5      10th & Chestnut 2017-01-01 05:00:00               0               1
# 6      10th & Chestnut 2017-01-01 06:00:00               0               1
# 7      10th & Chestnut 2017-01-01 07:00:00               0               0
# 8      10th & Chestnut 2017-01-01 08:00:00               0               0
# 9      10th & Chestnut 2017-01-01 09:00:00               0               0
# 10     10th & Chestnut 2017-01-01 10:00:00               1               0
# 11     10th & Chestnut 2017-01-01 11:00:00               0               0
# 12     10th & Chestnut 2017-01-01 12:00:00               0               0
# 13     10th & Chestnut 2017-01-01 13:00:00               0               1
# 14     10th & Chestnut 2017-01-01 14:00:00               0               0
# 15     10th & Chestnut 2017-01-01 15:00:00               2               0
# 16     10th & Chestnut 2017-01-01 16:00:00               2               0
# 17     10th & Chestnut 2017-01-01 17:00:00               1               0
# 18     10th & Chestnut 2017-01-01 18:00:00               1               1
# 19     10th & Chestnut 2017-01-01 19:00:00               0               0
#
#        Delta
# Order
# 0         -1
# 1          0
# 2          0
# 3          0
# 4          0
# 5          1
# 6          1
# 7          0
# 8          0
# 9          0
# 10        -1
# 11         0
# 12         0
# 13         1
# 14         0
# 15        -2
# 16        -2
# 17        -1
# 18         0
# 19         0

# %%
df_bikes_delta_final_year = df_bikes_delta_final.groupby(['Station Name']).sum().reset_index()

# %%
df_bikes_delta_final_year = df_bikes_delta_final_year.sort_values(['Station Name'])

# %%
df_bikes_delta_final_year.sort_values(['Delta'])
# Out:
#                        Station Name  Outgoing bikes  Incoming bikes  Delta
# 25                 20th & Fairmount            9601            7573  -2028
# 18             17th & Spring Garden            9759            7994  -1765
# 94                  Dornsife Center            5331            3571  -1760
# 39                    27th & Girard            5488            3985  -1503
# 32                 23rd & Fairmount            8967            7480  -1487
# ..                              ...             ...             ...    ...
# 110  Pennsylvania Convention Center            6470            7472   1002
# 103            Moyamensing & Tasker            6365            7520   1155
# 71                 4th & Bainbridge           12489           14119   1630
# 124                 Virtual Station             102            2280   2178
# 20                       18th & JFK           19271           24274   5003
#
# [126 rows x 4 columns]

# %%
df_bikes_delta_id = df_bikes[['start_station_name','start_station_id']].copy()
df_bikes_delta_id = df_bikes_delta_id.drop_duplicates(subset=['start_station_id'], keep='first', ignore_index=False)
df_bikes_delta_id = df_bikes_delta_id.sort_values(['start_station_name'])
df_bikes_delta_id['Order'] = np.arange(len(df_bikes_delta_id))
df_bikes_delta_id = df_bikes_delta_id.set_index('Order')

# %%
df_bikes_delta_id
# Out:
#                                       start_station_name  start_station_id
# Order
# 0                                        10th & Chestnut              3033
# 1                                         10th & Federal              3098
# 2                                 11th & Pine, Kahn Park              3007
# 3         11th & Poplar, John F. Street Community Center              3016
# 4                                            11th & Reed              3034
# ...                                                  ...               ...
# 121    The Children's Hospital of Philadelphia, Osler...              3129
# 122                     Thompson & Palmer, Adaire School              3153
# 123                              University City Station              3020
# 124                                      Virtual Station              3000
# 125                                    Welcome Park, NPS              3005
#
# [126 rows x 2 columns]

# %%
df_bikes_delta_final_year['start_station_id'] = df_bikes_delta_id['start_station_id']

# %%
df_bikes_delta_final_year
# Out:
#                                           Station Name  Outgoing bikes  \
# 0                                      10th & Chestnut            8304
# 1                                       10th & Federal            4622
# 2                               11th & Pine, Kahn Park           11808
# 3       11th & Poplar, John F. Street Community Center             715
# 4                                          11th & Reed            7737
# ..                                                 ...             ...
# 121  The Children's Hospital of Philadelphia, Osler...            4014
# 122                   Thompson & Palmer, Adaire School            1440
# 123                            University City Station           15801
# 124                                    Virtual Station             102
# 125                                  Welcome Park, NPS            4489
#
#      Incoming bikes  Delta  start_station_id
# 0              8546    242              3033
# 1              4848    226              3098
# 2             12244    436              3007
# 3               750     35              3016
# 4              8137    400              3034
# ..              ...    ...               ...
# 121            3777   -237              3129
# 122            1436     -4              3153
# 123           14433  -1368              3020
# 124            2280   2178              3000
# 125            5063    574              3005
#
# [126 rows x 5 columns]

# %%
df_bikes_delta_final_hours = df_bikes_delta_final.groupby(['Time']).sum()

# %%
df_bikes_delta_final_hours.head(10)
# Out:
#                      Outgoing bikes  Incoming bikes  Delta
# Time
# 2017-01-01 00:00:00              21              12     -9
# 2017-01-01 01:00:00              25              28      3
# 2017-01-01 02:00:00              15              18      3
# 2017-01-01 03:00:00               5               7      2
# 2017-01-01 04:00:00               4               2     -2
# 2017-01-01 05:00:00               4               6      2
# 2017-01-01 06:00:00               2               2      0
# 2017-01-01 07:00:00              10               7     -3
# 2017-01-01 08:00:00              15              16      1
# 2017-01-01 09:00:00              16              14     -2

# %% [markdown]
# # Visualization

# %%
import folium
from folium import plugins

# %%
latlong = pd.read_csv('../data/geocodes.csv').values.tolist()
for row in latlong:
   row[0] = int(row[0])

df_bikes.head()
# Out:
#       start_time       end_time  start_station_id  end_station_id  bike_id  \
# 0  1/1/2017 0:05  1/1/2017 0:16              3046            3041     5347
# 1  1/1/2017 0:21  1/1/2017 0:57              3110            3054     3364
# 2  1/1/2017 0:22  1/1/2017 0:57              3110            3054     2536
# 3  1/1/2017 0:27  1/1/2017 0:39              3041            3005     5176
# 4  1/1/2017 0:28  1/1/2017 0:36              3047            3124     5370
#
#   user_type           start_station_name     end_station_name  \
# 0  Indego30                 2nd & Market  Girard Station, MFL
# 1   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 2   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 3  Indego30          Girard Station, MFL    Welcome Park, NPS
# 4   Walk-up       Independence Mall, NPS     Race Street Pier
#
#    ride_duration_minutes start_time_rounded end_time_rounded
# 0                   11.0         2017-01-01       2017-01-01
# 1                   36.0         2017-01-01       2017-01-01
# 2                   35.0         2017-01-01       2017-01-01
# 3                   12.0         2017-01-01       2017-01-01
# 4                    8.0         2017-01-01       2017-01-01

# %%
## Putting together lat and long and ride History

# %%
def get_unique_station_ids():
   unique_station_ids = set(df_bikes['start_station_id'])
   id_mapped_to_station = []
   for id in unique_station_ids:
       this_station = []
       this_station.append(id)
       this_station.append(df_bikes.loc[df_bikes['start_station_id'] == id].iloc[0]['start_station_name'])
       id_mapped_to_station.append(this_station)
   return id_mapped_to_station

# %%
id_mapped_to_station = get_unique_station_ids()

def search_id(id):
   for row in latlong:
       if row[0] == id:
           return row

def search_name(id):
   for row in id_mapped_to_station:
       if row[0] == id:
           return row[1]

for row in latlong:
   row.append(search_name(row[0]))

df_bikes_delta_final_year["start_station_lat"] = df_bikes_delta_final_year.apply(lambda x: search_id(x['start_station_id'])[1] ,  axis=1)
df_bikes_delta_final_year["start_station_lng"] = df_bikes_delta_final_year.apply(lambda x: search_id(x['start_station_id'])[2] ,  axis=1)
df_bikes_delta_final_year["end_station_lat"] = df_bikes_delta_final_year.apply(lambda x: search_id(x['start_station_id'])[1] ,  axis=1)
df_bikes_delta_final_year["end_station_lng"] = df_bikes_delta_final_year.apply(lambda x: search_id(x['start_station_id'])[2] ,  axis=1)

# %%
start_map = folium.Map(location=(39.95, -75.17), zoom_start=12, control_scale=True, max_zoom=20)
start_map.add_child(plugins.HeatMap(np.array(df_bikes_delta_final_year[['start_station_lat','start_station_lng','Delta']]), radius=15))

#TODO: Teil des ganzen anzeigen

for el in latlong:
   folium.CircleMarker(radius=2, location=[el[1],el[2]], color='black', fill_color='black', popup=el[3]).add_to(start_map)


start_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_088d9bfd1d0c4366a03b23503174a233%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_088d9bfd1d0c4366a03b23503174a233%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_088d9bfd1d0c4366a03b23503174a233%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_088d9bfd1d0c4366a03b23503174a233%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
